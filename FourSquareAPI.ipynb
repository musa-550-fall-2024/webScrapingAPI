# %% [markdown]
# ## **Four Square APIs**
#
# This tutorial provides a brief description of how getting started with Foursquare API. You will also find a good tutorial here:
# https://www.kaggle.com/code/kristoft/tutorial-foursquare-api-search

# %% [markdown]
# **Getting Started**
#
# Foursquare API provides a range of tools for developers to incorporate the up-to-date location data to enhance their projects.
#
# To start using Foursquare, first, let’s create a new account at https://developer.foursquare.com/ . The default account is called Sandbox Account. Sandbox Account provides you a limited set of tools, for instance, you‘ll be able to make only 950 Regular Calls / Day, and get 1 Photo and 1 Tip per Venue. Not too much, but it should be enough for a “toy” dataset (sure, you may also upgrade your account for future projects). Foursquare provides a simple UI to manage your account and to check your daily stats (like how many calls did you make). Once the account is created, you will be assigned credentials: the Client ID and the Client Secret.
#
# Ok, all set up and we can jump into coding. First and foremost, let’s import some necessary libraries: pandas.io.json(to tranforming json file into a pandas dataframe library), folium (plotting library), geopy.geocoders (module to convert an address into latitude and longitude values), and requests (library to handle requests).

# %%
# !pip install geopy
from pandas import json_normalize
import folium
import pandas as pd
from geopy.geocoders import Nominatim
import requests
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 3.2 MB/s eta 0:00:0000:01
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %% [markdown]
# Next, lets define our Foursquare credentials and version into python code:

# %%
CLIENT_ID = "AX1O0GXCKC2YOCKBYWQRXPXQFLZBAZE5PKHGOPA5QRMJQWKI" # your Foursquare ID
CLIENT_SECRET = "XH34Z0ZQXNJSOWAL5EP4000O0UBYMJVI1UEFJTPKO0SZF24G" # your Foursquare Secret
VERSION = "20180604"
LIMIT = 100

# %% [markdown]
# Now, let’s assume you just moved to a new place which called UNC-Charlotte, and you want to explore your neighbourhood. So, let’s define a query to search the top 100 venues that are within 5000 meters from UNCC.

# %%
# Select first building (which in our case is Penn):
neighborhood_name = 'Penn University'
neighborhood_latitude = 39.952
neighborhood_longitude = -75.193

# limit of number of venues returned by Foursquare API
LIMIT = 100
radius = 2500

# %% [markdown]
# And now we define the corresponding URL and send the GET Request to Foursquare API and examine the results.

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    neighborhood_latitude,
    neighborhood_longitude,
    radius,
    LIMIT)
results = requests.get(url).json()
print(results)
# Out:
# {'meta': {'code': 200, 'requestId': '671a6c1948953d5437b530b0'}, 'response': {'queryRefinements': {'target': {'type': 'path', 'url': '/venue/explore', 'params': {'ll': '39.952000,-75.193000', 'radius': '2500'}}, 'refinements': [{'query': 'Food'}, {'query': 'Nightlife'}, {'query': 'Coffee'}, {'query': 'Shops'}, {'query': 'Arts'}, {'query': 'Outdoors'}]}, 'suggestedFilters': {'header': 'Tap to show:', 'filters': [{'name': '$-$$$$', 'key': 'price'}, {'name': 'Open now', 'key': 'openNow'}]}, 'headerLocation': 'Philadelphia', 'headerFullLocation': 'Philadelphia', 'headerLocationGranularity': 'city', 'totalResults': 208, 'suggestedBounds': {'ne': {'lat': 39.974500022500024, 'lng': -75.16370373082528}, 'sw': {'lat': 39.92949997749997, 'lng': -75.22229626917472}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '40b28c80f964a520f7f81ee3', 'name': 'White Dog Cafe', 'contact': {'phone': '2153869224', 'formattedPhone': '(215) 386-9224', 'twitter': 'whitedogphilly', 'facebook': '98469539146', 'facebookUsername': 'whitedogcafe', 'facebookName': 'White Dog Cafe'}, 'location': {'address': '3420 Sansom St', 'lat': 39.95354810000001, 'lng': -75.1929486, 'labeledLatLngs': [{'label': 'entrance', 'lat': 39.953622, 'lng': -75.192902}, {'label': 'display', 'lat': 39.95354810000001, 'lng': -75.1929486}], 'distance': 172, 'postalCode': '19104', 'cc': 'US', 'city': 'Philadelphia', 'state': 'PA', 'country': 'United States', 'formattedAddress': ['3420 Sansom St', 'Philadelphia, PA 19104', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d14e941735', 'name': 'American Restaurant', 'pluralName': 'American Restaurants', 'shortName': 'American', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'categoryCode': 13068, 'mapIcon': 'fsq-dining', 'primary': True}], 'verified': False, 'stats': {'tipCount': 94, 'usersCount': 4843, 'checkinsCount': 7693}, 'url': 'http://www.whitedog.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'header': 'According to the Foursquare community, this place is an 8.8 out of 10.', 'rating': 8.8, 'ratingColor': '73CF42', 'ratingSignals': 379, 'explanation': "We take into account visits and input from our community. You'll see a number on places based off of ratings and tips written by people like you.", 'ratingCategory': 'great', 'deliveryProviders': [{'id': '5867624', 'url': 'https://www.grubhub.com/restaurant/white-dog-cafe-3420-sansom-st-philadelphia/5867624?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=5867624', 'provider': {'name': 'grubhub', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_grubhub_20180129.png'}}}], 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/white-dog-cafe/40b28c80f964a520f7f81ee3/menu', 'mobileUrl': 'https://foursquare.com/v/40b28c80f964a520f7f81ee3/device_menu', 'externalUrl': 'https://whitedog.com/universitycity/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'hours': {'status': 'Open until 21:00', 'richStatus': {'entities': [], 'text': 'Open until 21:00'}, 'isOpen': True, 'isLocalHoliday': False}, 'photos': {'count': 0, 'groups': []}, 'createdAt': 1085443200, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'popularityByGeo': 0.9829680079050543}, 'photo': {'id': '644ef546aed68036d7f961a8', 'createdAt': 1682896198, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3134736_cWwz6c0bFVnnd3_chhnxC0a17EBJZYuXxWlYaGqDJ6E.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'tips': [{'id': '4e8f58cc0cd6d5e025a5aea2', 'createdAt': 1318017228, 'text': 'Pet owners can dine alfresco at the White Dog ...

# %% [markdown]
# Next, get relevant part of JSON and transform it into a pandas dataframe:

# %%
# assign relevant part of JSON to venues
venues = results['response']['groups'][0]['items']

# tranform venues into a pandas dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                 tips  \
# 0  [{'id': '4e8f58cc0cd6d5e025a5aea2', 'createdAt...
# 1  [{'id': '531dbf1a11d274d268865546', 'createdAt...
# 2  [{'id': '5d331f9d429bfc00256ac685', 'createdAt...
# 3  [{'id': '4c8f9a71c86595213c360929', 'createdAt...
# 4  [{'id': '5b19bca7121384002cc412f7', 'createdAt...
#
#                        referralId  reasons.count  \
# 0  e-0-40b28c80f964a520f7f81ee3-0              0
# 1  e-0-531740af498e0b817696bbb1-1              0
# 2  e-0-584601eb03e29a3ad375b50b-2              0
# 3  e-0-3fd66200f964a52009ee1ee3-3              0
# 4  e-0-5aae8fdcdee770732ce8972a-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                    venue.name venue.contact.phone  \
# 0  40b28c80f964a520f7f81ee3                White Dog Cafe          2153869224
# 1  531740af498e0b817696bbb1                Federal Donuts          2672758489
# 2  584601eb03e29a3ad375b50b  The Study at University City          2153871400
# 3  3fd66200f964a52009ee1ee3                           Pod          2153871803
# 4  5aae8fdcdee770732ce8972a                        Goldie          2672390777
#
#   venue.contact.formattedPhone venue.contact.twitter venue.contact.facebook  \
# 0               (215) 386-9224        whitedogphilly            98469539146
# 1               (267) 275-8489         federaldonuts                    NaN
# 2               (215) 387-1400                   NaN                    NaN
# 3               (215) 387-1803       StarrRestaurant            81183216293
# 4               (267) 239-0777                   NaN                    NaN
#
#    ...                                       photo.suffix photo.width  \
# 0  ...  /3134736_cWwz6c0bFVnnd3_chhnxC0a17EBJZYuXxWlYa...        1440
# 1  ...  /3781018_VNWlIBJS0b4UEx4tUa_Gdt4i3mnHKgEO-39bP...         720
# 2  ...  /523630644_LbRWxwfZO8jIORuQ7OoW_cbomYhy4GNoadm...        1080
# 3  ...  /6531240_U29i-VVz-tOGOIHzgHHXpbD46eV0Y6afKgpiP...         720
# 4  ...  /528180147_KfJdalnq7_zz0mMPit9ZpSVeREHe_h6IOgU...         975
#
#   photo.height  photo.visibility  venue.location.crossStreet  \
# 0         1920            public                         NaN
# 1          960            public                  at 34th St
# 2         1920            public                         NaN
# 3          960            public             btw 36th & 37th
# 4         1920            public                         NaN
#
#   venue.venuePage.id  venue.storeId venue.venueRatingBlacklisted  \
# 0                NaN            NaN                          NaN
# 1                NaN            NaN                          NaN
# 2                NaN            NaN                          NaN
# 3           32706361            NaN                          NaN
# 4                NaN            NaN                          NaN
#
#   venue.contact.instagram venue.location.neighborhood
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
# [5 rows x 75 columns]

# %% [markdown]
# Define information of interest and filter the dataframe

# %%
# filter columns
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']

    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =dataframe.loc[:, filtered_columns]# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head(10)
# Out:
#                                                 name           categories  \
# 0                                     White Dog Cafe  American Restaurant
# 1                                     Federal Donuts           Donut Shop
# 2                       The Study at University City                Hotel
# 3                                                Pod     Asian Restaurant
# 4                                             Goldie   Falafel Restaurant
# 5  University of Pennsylvania Museum of Archaeolo...       History Museum
# 6                                    World Cafe Live          Music Venue
# 7                                           Avril 50          Coffee Shop
# 8                                          Penn Park                 Park
# 9                                        Louie Louie           Restaurant
#
#          lat        lng
# 0  39.953548 -75.192949
# 1  39.953671 -75.193126
# 2  39.954434 -75.190067
# 3  39.953971 -75.196037
# 4  39.953156 -75.192737
# 5  39.949507 -75.191684
# 6  39.952214 -75.185151
# 7  39.953538 -75.192546
# 8  39.951241 -75.185166
# 9  39.953511 -75.196071

# %% [markdown]
# Finally, lets visualize the venues around Penn. For this purpose I use Folium library (Folium is completely free). Generating the map is straigtforward in Folium. We only create a Folium Map object and display it. So, I generate a map centred around the Penn campus. Bellow is the python code:

# %%
venues_map = folium.Map(location=[neighborhood_latitude, neighborhood_longitude], zoom_start=15)

folium.features.CircleMarker(
    [neighborhood_latitude, neighborhood_longitude],
    radius=10,
    color='red',
    popup='UPENN',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)


# add all venues as blue circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b412b7a7702f1df37aa8b255832a0704 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b412b7a7702f1df37aa8b255832a0704&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b412b7a7702f1df37aa8b255832a0704 = L.map(
#                 &quot;map_b412b7a7702f1df37aa8b255832a0704&quot;,
#                 {
#                     center: [39.952, -75.193],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb3dce228418b1605d94076b08e9b14e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb3dce228418b1605d94076b08e9b14e.addTo(map_b412b7a7702f1df37aa8b255832a0704);
#
#
#             var circle_marker_380fbde5829bfbacff1f3c8de377ea9b = L.circleMarker(
#                 [39.952, -75.193],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b412b7a7702f1df37aa8b255832a0704);
#
#
#         var popup_4a12ae13120799d2366e7f7e1d772095 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_087c91f37229d28511e389fe43c335ec = $(`&lt;div id=&quot;html_087c91f37229d28511e389fe43c335ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UPENN&lt;/div&gt;`)[0];
#                 popup_4a12ae13120799d2366e7f7e1d772095.setContent(html_087c91f37229d28511e389fe43c335ec);
#
#
#
#         circle_marker_380fbde5829bfbacff1f3c8de377ea9b.bindPopup(popup_4a12ae13120799d2366e7f7e1d772095)
#         ;
#
#
#
#
#             var circle_marker_23089c1c34aad42dcab0652a84fe12d3 = L.circleMarker(
#                 [39.95354810000001, -75.1929486],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b412b7a7702f1df37aa8b255832a0704);
#
#
#         var popup_4020091950f2b52365f2dfba36f816da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77aabd039b36d4f6b84eef56f0d25bdc = $(`&lt;div id=&quot;html_77aabd039b36d4f6b84eef56f0d25bdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;White Dog Cafe&lt;/div&gt;`)[0];
#                 popup_4020091950f2b52365f2dfba36f816da.setContent(html_77aabd039b36d4f6b84eef56f0d25bdc);
#
#
#
#         circle_marker_23089c1c34aad42dcab0652a84fe12d3.bindPopup(popup_4020091950f2b52365f2dfba36f816da)
#         ;
#
#
#
#
#             var circle_marker_88e0185d34ec6cfc82376f5f409b743c = L.circleMarker(
#                 [39.95367121220996, -75.19312642390238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b412b7a7702f1df37aa8b255832a0704);
#
#
#         var popup_022c3fc4820dbd5c3515f7c4103ad049 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_726591421e6c54d1a6c62a9793af74aa = $(`&lt;div id=&quot;html_726591421e6c54d1a6c62a9793af74aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Federal Donuts&lt;/div&gt;`)[0];
#                 popup_022c3fc4820dbd5c3515f7c4103ad049.setContent(html_726591421e6c54d1a6c62a9793af74aa);
#
#
#
#         circle_marker_88e0185d34ec6cfc82376f5f409b743c.bindPopup(popup_022c3fc4820dbd5c3515f7c4103ad049)
#         ;
#
#
#
#
#             var circle_marker_583cb828ca9d72176fce566cdf40b815 = L.circleMarker(
#                 [39.954433968575565, -75.19006695785826],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;,
