# %% [markdown]
# # Mapping Air Quality with API
# In this brief presentation, I explain how we can gather air pollution data for a particular location, using an *Application Programming Interface*.
#
# ![image.png](data:image/png;base64,...)
#
# An API allows a user to request specific data (e.g. on air pollution, routes...) to a server that contains that information. If the authentification is approved, the server will return data to the user through the API. That data is often returned in an XML or JSON format.

# %% [markdown]
# ## Increased interest in environmental health and modeling exposure to contaminants found in water, food or the air we breathe.
#
# ![googleAirQuality.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **`airpyllution`**
#
# First we import the package we may need, in our case `airpyllution`, and mapping libraries.

# %%
# Import package
! pip install airpyllution

#To use the package, import the package with the following commands:
from airpyllution.airpyllution import get_air_pollution
from airpyllution.airpyllution import get_pollution_history
from airpyllution.airpyllution import get_pollution_forecast

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime
import altair as alt
# Out:
# Collecting airpyllution
#   Obtaining dependency information for airpyllution from https://files.pythonhosted.org/packages/9a/95/dd1d64188a58b7e868ca51c2539acf35618ba090b3019760734295bc92be/airpyllution-2.0.1-py3-none-any.whl.metadata
#   Downloading airpyllution-2.0.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting DateTime<5.0,>=4.3 (from airpyllution)
#   Obtaining dependency information for DateTime<5.0,>=4.3 from https://files.pythonhosted.org/packages/24/1a/cdac35c7627578939d509d436123328dea641c24e9f76c15a9bbe1016af7/DateTime-4.9-py2.py3-none-any.whl.metadata
#   Downloading DateTime-4.9-py2.py3-none-any.whl.metadata (33 kB)
# Collecting altair<5.0.0,>=4.2.0 (from airpyllution)
#   Obtaining dependency information for altair<5.0.0,>=4.2.0 from https://files.pythonhosted.org/packages/18/62/47452306e84d4d2e67f9c559380aeb230f5e6ca84fafb428dd36b96a99ba/altair-4.2.2-py3-none-any.whl.metadata
#   Downloading altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting altair-viewer<0.5.0,>=0.4.0 (from airpyllution)
#   Obtaining dependency information for altair-viewer<0.5.0,>=0.4.0 from https://files.pythonhosted.org/packages/f1/e6/0890752f10ba12cfff4d6a86771e4881d259b735fb6f4de9a34f4a0b0874/altair_viewer-0.4.0-py3-none-any.whl.metadata
#   Downloading altair_viewer-0.4.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting black<22.0,>=21.12b0 (from airpyllution)
#   Obtaining dependency information for black<22.0,>=21.12b0 from https://files.pythonhosted.org/packages/9b/27/b2f98b627738b02dcac06ae9e2ab13f14ab906fe6dd6366050c76883d4b5/black-21.12b0-py3-none-any.whl.metadata
#   Downloading black-21.12b0-py3-none-any.whl.metadata (39 kB)
# Collecting mock<5.0.0,>=4.0.3 (from airpyllution)
#   Obtaining dependency information for mock<5.0.0,>=4.0.3 from https://files.pythonhosted.org/packages/5c/03/b7e605db4a57c0f6fba744b11ef3ddf4ddebcada35022927a2b5fc623fdf/mock-4.0.3-py3-none-any.whl.metadata
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from airpyllution) (1.24.4)
# Collecting pandas<2.0.0,>=1.3.5 (from airpyllution)
#   Obtaining dependency information for pandas<2.0.0,>=1.3.5 from https://files.pythonhosted.org/packages/5f/34/b7858bb7d6d6bf4d9df1dde777a11fcf3ff370e1d1b3956e3d0fcca8322c/pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata
#   Downloading pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: plotly<6.0.0,>=5.5.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from airpyllution) (5.21.0)
# Collecting python-dotenv<0.20.0,>=0.19.2 (from airpyllution)
#   Obtaining dependency information for python-dotenv<0.20.0,>=0.19.2 from https://files.pythonhosted.org/packages/0e/f1/0317f4b2c5284075a2154fe95539b43c0acecbcb86fe80fcb2645803edd9/python_dotenv-0.19.2-py2.py3-none-any.whl.metadata
#   Downloading python_dotenv-0.19.2-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from airpyllution) (2.31.0)
# Collecting responses<0.18.0,>=0.17.0 (from airpyllution)
#   Obtaining dependency information for responses<0.18.0,>=0.17.0 from https://files.pythonhosted.org/packages/3c/f7/3925be6f7c251b331095d3e7302fdf3c7599284b5a616bd4c90fca7ace45/responses-0.17.0-py2.py3-none-any.whl.metadata
#   Downloading responses-0.17.0-py2.py3-none-any.whl.metadata (27 kB)
# Collecting vega-datasets<0.10.0,>=0.9.0 (from airpyllution)
#   Obtaining dependency information for vega-datasets<0.10.0,>=0.9.0 from https://files.pythonhosted.org/packages/e6/9f/ca52771fe972e0dcc5167fedb609940e01516066938ff2ee28b273ae4f29/vega_datasets-0.9.0-py3-none-any.whl.metadata
#   Downloading vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting entrypoints (from altair<5.0.0,>=4.2.0->airpyllution)
#   Obtaining dependency information for entrypoints from https://files.pythonhosted.org/packages/35/a8/365059bbcd4572cbc41de17fd5b682be5868b218c3c5479071865cab9078/entrypoints-0.4-py3-none-any.whl.metadata
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jinja2 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.0->airpyllution) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.0->airpyllution) (4.19.1)
# Requirement already satisfied: toolz in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.0->airpyllution) (0.12.0)
# Collecting altair-data-server>=0.4.0 (from altair-viewer<0.5.0,>=0.4.0->airpyllution)
#   Obtaining dependency information for altair-data-server>=0.4.0 from https://files.pythonhosted.org/packages/e7/a3/0e7651adce146c17eea516ffcb530f7ee769671e59395bc10838eca827db/altair_data_server-0.4.1-py3-none-any.whl.metadata
#   Downloading altair_data_server-0.4.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: click>=7.1.2 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from black<22.0,>=21.12b0->airpyllution) (8.1.7)
# Requirement already satisfied: platformdirs>=2 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from black<22.0,>=21.12b0->airpyllution) (3.11.0)
# Collecting tomli<2.0.0,>=0.2.6 (from black<22.0,>=21.12b0->airpyllution)
#   Obtaining dependency information for tomli<2.0.0,>=0.2.6 from https://files.pythonhosted.org/packages/05/e4/74f9440db36734d7ba83c574c1e7024009ce849208a41f90e94a134dc6d1/tomli-1.2.3-py3-none-any.whl.metadata
#   Downloading tomli-1.2.3-py3-none-any.whl.metadata (9.1 kB)
# Collecting pathspec<1,>=0.9.0 (from black<22.0,>=21.12b0->airpyllution)
#   Obtaining dependency information for pathspec<1,>=0.9.0 from https://files.pythonhosted.org/packages/cc/20/ff623b09d963f88bfde16306a54e12ee5ea43e9b597108672ff3a408aad6/pathspec-0.12.1-py3-none-any.whl.metadata
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from black<22.0,>=21.12b0->airpyllution) (4.8.0)
# Collecting mypy-extensions>=0.4.3 (from black<22.0,>=21.12b0->airpyllution)
#   Obtaining dependency information for mypy-extensions>=0.4.3 from https://files.pythonhosted.org/packages/2a/e2/5d3f6ada4297caebe1a2add3b126fe800c96f56dbe5d1988a2cbe0b267aa/mypy_extensions-1.0.0-py3-none-any.whl.metadata
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting zope.interface (from DateTime<5.0,>=4.3->airpyllution)
#   Obtaining dependency information for zope.interface from https://files.pythonhosted.org/packages/33/41/328372febe88b50cb1c77d99fd3ee8e628fb125bd26b38b5351f8b9bdcbb/zope.interface-7.1.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata
#   Downloading zope.interface-7.1.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from DateTime<5.0,>=4.3->airpyllution) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from pandas<2.0.0,>=1.3.5->airpyllution) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from plotly<6.0.0,>=5.5.0->airpyllution) (8.2.3)
# Requirement already satisfied: packaging in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from plotly<6.0.0,>=5.5.0->airpyllution) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from requests<3.0.0,>=2.27.1->airpyllution) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from requests<3.0.0,>=2.27.1->airpyllution) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from requests<3.0.0,>=2.27.1->airpyllution) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from requests<3.0.0,>=2.27.1->airpyllution) (2024.7.4)
# Requirement already satisfied: six in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from responses<0.18.0,>=0.17.0->airpyllution) (1.16.0)
# Collecting portpicker (from altair-data-server>=0.4.0->altair-viewer<0.5.0,>=0.4.0->airpyllution)
#   Obtaining dependency information for portpicker from https://files.pythonhosted.org/packages/32/2d/440e4d7041fff89f28f483733eb617127aa866135c2dc719e05893f089e1/portpicker-1.6.0-py3-none-any.whl.metadata
#   Downloading portpicker-1.6.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tornado in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from altair-data-server>=0.4.0->altair-viewer<0.5.0,>=0.4.0->airpyllution) (6.3.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.0->airpyllution) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.0->airpyllution) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.0->airpyllution) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.0->airpyllution) (0.10.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from jinja2->altair<5.0.0,>=4.2.0->airpyllution) (2.1.3)
# Requirement already satisfied: setuptools in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from zope.interface->DateTime<5.0,>=4.3->airpyllution) (68.1.2)
# Requirement already satisfied: psutil in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from portpicker->altair-data-server>=0.4.0->altair-viewer<0.5.0,>=0.4.0->airpyllution) (5.9.8)
# Downloading airpyllution-2.0.1-py3-none-any.whl (14 kB)
# Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 12.1 MB/s eta 0:00:00a 0:00:01
# Downloading altair_viewer-0.4.0-py3-none-any.whl (844 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 844.5/844.5 kB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading black-21.12b0-py3-none-any.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.7/156.7 kB 3.5 MB/s eta 0:00:0000:01
# Downloading DateTime-4.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 1.9 MB/s eta 0:00:00
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Using cached pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
# Downloading python_dotenv-0.19.2-py2.py3-none-any.whl (17 kB)
# Downloading responses-0.17.0-py2.py3-none-any.whl (38 kB)
# Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.8/210.8 kB 6.3 MB/s eta 0:00:00
# Downloading altair_data_server-0.4.1-py3-none-any.whl (12 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading zope.interface-7.1.1-cp310-cp310-macosx_10_9_x86_64.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 5.2 MB/s eta 0:00:00:00:01
# Downloading portpicker-1.6.0-py3-none-any.whl (16 kB)
# Installing collected packages: zope.interface, tomli, python-dotenv, portpicker, pathspec, mypy-extensions, mock, entrypoints, responses, pandas, DateTime, black, vega-datasets, altair, altair-data-server, altair-viewer, airpyllution
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.1
#     Uninstalling tomli-2.0.1:
#       Successfully uninstalled tomli-2.0.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: altair
#     Found existing installation: altair 5.3.0
#     Uninstalling altair-5.3.0:
#       Successfully uninstalled altair-5.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# Successfully installed DateTime-4.9 airpyllution-2.0.1 altair-4.2.2 altair-data-server-0.4.1 altair-viewer-0.4.0 black-21.12b0 entrypoints-0.4 mock-4.0.3 mypy-extensions-1.0.0 pandas-1.5.3 pathspec-0.12.1 portpicker-1.6.0 python-dotenv-0.19.2 responses-0.17.0 tomli-1.2.3 vega-datasets-0.9.0 zope.interface-7.1.1

# %% [markdown]
# ### Retrieve historic pollution data with specified date range and location:
#
# Here we extract the pollution (using **get_pollution_history**) for the city of Philadelphia for a particular time range. Note that the time are expressed as unix times.

# %%
df = get_pollution_history(1729200000, 1729733852, 39.952583, -75.165222, '635948b768a2268ceccb06606c403863')

#unix time stamps: https://www.unixtimestamp.com/

#Converting date/time strings to datetime objects
df['Date'] = pd.to_datetime(df['dt'])

#Setting a datetime column as a dataframe index
df = df.set_index('Date')

#Spagetthi plot - https://www.datacamp.com/tutorial/matplotlib-time-series-line-plot
plt.plot(df.index, df['o3'])

# %% [markdown]
# ### Improve the figure a bit...

# %%
# Create the figure and axes
fig, ax = plt.subplots()

# Iterate over the data columns
listCol = df.columns

for contaminant in listCol[0:-1]:
    x = df.index
    y = df[contaminant]

    # Trime
#    ax.plot(x, y, label=contaminant)
    ax.plot(x, y / y.iloc[0], label=contaminant)

# Format and add a legend
ax.set_title("Contamination, Normalized to Mon Oct 16 2023")
#ax.set_xticks(["min(df['dt'])", "max(df['dt'])"])
ax.tick_params(axis='x', labelrotation=90)
ax.legend(fontsize=10);

# %% [markdown]
# ## Get pollution forecast for the next 5 days.

# %%
import altair as alt
alt.renderers.enable("html");

get_pollution_forecast(39.952583, -75.165222, '635948b768a2268ceccb06606c403863')
# Out:
# alt.FacetChart(...)

# %% [markdown]
# # `OpenWeatherMap`
#
# Here we pass a request to `openweathermap` to get the pollution at this particular moment at a particular place (as set in lat and long).

# %%
from urllib.request import urlopen
import json
import datetime

url_request = "http://api.openweathermap.org/data/2.5/air_pollution?lat=39.952583&lon=-75.165222&appid=635948b768a2268ceccb06606c403863"
url_sourceCode = urlopen(url_request).read()
response = json.loads(url_sourceCode)
X = response.get("list")[0]
contaminants = X.get("components")
time = X.get("dt")
exactTime = datetime.datetime.fromtimestamp(time)

print("Pollution in Philadelphia at " + str(exactTime) + " !! GMT -2")
for key in contaminants:
    print(key, "->", contaminants[key])
# Out:
# Pollution in Philadelphia at 2024-10-24 12:06:44 !! GMT -2
# co -> 277.04
# no -> 2.29
# no2 -> 6.43
# o3 -> 57.94
# so2 -> 2.65
# pm2_5 -> 1.63
# pm10 -> 2.23
# nh3 -> 0.59

# %% [markdown]
# # Getting pollution information every so often
# sleep time = 1500sec

# %%
from urllib.request import urlopen
import json
import datetime
import time

i=0
while i <20:
  url_request="http://api.openweathermap.org/data/2.5/air_pollution?lat=50.850346&lon=4.351721&appid=635948b768a2268ceccb06606c403863"
  url_sourceCode = urlopen(url_request).read()
  response = json.loads(url_sourceCode)
  X = response.get("list")[0]
  contaminants = X.get("components")
  timeTime = X.get("dt")
  exactTime = datetime.datetime.fromtimestamp(timeTime)

  print("Pollution in Brussels at " + str(exactTime) + " !! GMT -2")
  for key in contaminants:
    print(key, "->", contaminants[key])

  time.sleep(1500)
  i+=1
# Out:
# Pollution in Brussels at 2024-10-24 12:06:53 !! GMT -2
# co -> 307.08
# no -> 1.7
# no2 -> 28.79
# o3 -> 25.39
# so2 -> 3.79
# pm2_5 -> 8.77
# pm10 -> 10.24
# nh3 -> 2.91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 20
#      17 for key in contaminants:
#      18   print(key, "->", contaminants[key])
# ---> 20 time.sleep(1500)
#      21 i+=1
#
# KeyboardInterrupt:

# %% [markdown]
# # Getting pollution data for Belgium on a predefined grid

# %% [markdown]
# ## Import necessary libraries

# %%
import geopandas as gpd
import altair as alt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from shapely.geometry import Point, Polygon
import os
import glob
from urllib.request import urlopen
import json
import datetime
import time
# %matplotlib inline


#data = !wget "https://stacks.stanford.edu/file/druid:hs337qd4914/data.zip"
#print(data)
#!unzip data
country = gpd.read_file("data/BEL_ADM0.shp")
country.head()
country['geometry'].iloc[0]

#get extent boundaries
minX = country.bounds['minx']
minY = country.bounds['miny']
maxY = country.bounds['maxy']
maxX = country.bounds['maxx']

#how dense> Higher number = more points
spacing = 0.1
#create a grid around country

xmin, ymin, xmax, ymax = country.total_bounds


xcoords = [c for c in np.arange(xmin, xmax, spacing)] #Create x coordinates
ycoords = [c for c in np.arange(ymin, ymax, spacing)] #And y

coordinate_pairs = np.array(np.meshgrid(xcoords, ycoords)).T.reshape(-1, 2) #Create all combinations of xy coordinates
geometries = gpd.points_from_xy(coordinate_pairs[:,0], coordinate_pairs[:,1]) #Create a list of shapely points

pointdf = gpd.GeoDataFrame(geometry=geometries, crs=country.crs) #Create the point df
pointdf.to_file('polygongrid.shp')

insidePts = pointdf.clip(country)
insidePts['x'] = insidePts.geometry.x
insidePts['y'] = insidePts.geometry.y
#creating empty series
insidePts['co']=np.ones(len(insidePts))*0
insidePts['no']=np.ones(len(insidePts))*0
insidePts['no2']=np.ones(len(insidePts))*0
insidePts['o3']=np.ones(len(insidePts))*0
insidePts['so2']=np.ones(len(insidePts))*0
insidePts['pm2_5']=np.ones(len(insidePts))*0
insidePts['pm10']=np.ones(len(insidePts))*0
insidePts['nh3']=np.ones(len(insidePts))*0
insidePts['time']=np.ones(len(insidePts))*0

i=0
while i <len(insidePts):
  lat = list(insidePts.geometry)[i].y
  long = list(insidePts.geometry)[i].x
  url_request="http://api.openweathermap.org/data/2.5/air_pollution?lat="+str(lat)+"&lon="+str(long)+"&appid=635948b768a2268ceccb06606c403863"
  url_sourceCode = urlopen(url_request).read()
  response = json.loads(url_sourceCode)
  X = response.get("list")[0]
  contaminants = X.get("components")
  #print(X)
  #print(contaminants)
  #timeTime = X.get("dt")
  #insidePts['time'][i] = datetime.datetime.fromtimestamp(timeTime)
  for key in contaminants:
    insidePts[key].iloc[i] = contaminants[key]
  print("left to calculate..." + str(len(insidePts)-i))
  i=i+1

insidePts.head()
# Out:
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/delmelle/miniforge3/lib/python3.10/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /var/folders/lv/8xb4hscx2hs0c0fwhd2bnjy80000gn/T/ipykernel_51528/2837007306.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insidePts[key].iloc[i] = contaminants[key]
# left to calculate...388
# left to calculate...387
# left to calculate...386
# left to calculate...385
# left to calculate...384
# left to calculate...383
# left to calculate...382
# left to calculate...381
# left to calculate...380
# left to calculate...379
# left to calculate...378
# left to calculate...377
# left to calculate...376
# left to calculate...375
# left to calculate...374
# left to calculate...373
# left to calculate...372
# left to calculate...371
# left to calculate...370
# left to calculate...369
# left to calculate...368
# left to calculate...367
# left to calculate...366
# left to calculate...365
# left to calculate...364
# left to calculate...363
# left to calculate...362
# left to calculate...361
# left to calculate...360
# left to calculate...359
# left to calculate...358
# left to calculate...357
# left to calculate...356
# left to calculate...355
# left to calculate...354
# left to calculate...353
# left to calculate...352
# left to calculate...351
# left to calculate...350
# left to calculate...349
# left to calculate...348
# left to calculate...347
# left to calculate...346
# left to calculate...345
# left to calculate...344
# left to calculate...343
# left to calculate...342
# left to calculate...341
# left to calculate...340
# left to calculate...339
# left to calculate...338
# left to calculate...337
# left to calculate...336
# left to calculate...335
# left to calculate...334
# left to calculate...333
# left to calculate...332
# left to calculate...331
# left to calculate...330
# left to calculate...329
# left to calculate...328
# left to calculate...327
# left to calculate...326
# left to calculate...325
# left to calculate...324
# left to calculate...323
# left to calculate...322
# left to calculate...321
# left to calculate...320
# left to calculate...319
# left to calculate...318
# left to calculate...317
# left to calculate...316
# left to calculate...315
# left to calculate...314
# left to calculate...313
# left to calculate...312
# left to calculate...311
# left to calculate...310
# left to calculate...309
# left to calculate...308
# left to calculate...307
# left to calculate...306
# left to calculate...305
# left to calculate...304
# left to calculate...303
# left to calculate...302
# left to calculate...301
# left to calculate...300
# left to calculate...299
# left to calculate...298
# left to calculate...297
# left to calculate...296
# left to calculate...295
# left to calculate...294
# left to calculate...293
# left to calculate...292
# left to calculate...291
# left to calculate...290
# left to calculate...289
# left to calculate...288
# left to calculate...287
# left to calculate...286
# left to calculate...285
# left to calculate...284
# left to calculate...283
# left to calculate...282
# left to calculate...281
# left to calculate...280
# left to calculate...279
# left to calculate...278
# left to calculate...277
# left to calculate...276
# left to calculate...275
# left to calculate...274
# left to calculate...273
# left to calculate...272
# left to calculate...271
# left to calculate...270
# left to calculate...269
# left to calculate...268
# left to calculate...267
# left to calculate...266
# left to calculate...265
# left to calculate...264
# left to calculate...263
# left to calculate...262
# left to calculate...261
# left to calculate...260
# left to calculate...259
# left to calculate...258
# left to calculate...257
# left to calculate...256
# left to calculate...255
# left to calculate...254
# left to calculate...253
# left to calculate...252
# left to calculate...251
# left to calculate...250
# left to calculate...249
# left to calculate...248
# left to calculate...247
# left to calculate...246
# left to calculate...245
# left to calculate...244
# left to calculate...243
# left to calculate...242
# left to calculate...241
# left to calculate...240
# left to calculate...239
# left to calculate...238
# left to calculate...237
# left to calculate...236
# left to calculate...235
# left to calculate...234
# left to calculate...233
# left to calculate...232
# left to calculate...231
# left to calculate...230
# left to calculate...229
# left to calculate...228
# left to calculate...227
# left to calculate...226
# left to calculate...225
# left to calculate...224
# left to calculate...223
# left to calculate...222
# left to calculate...221
# left to calculate...220
# left to calculate...219
# left to calculate...218
# left to calculate...217
# left to calculate...216
# left to calculate...215
# left to calculate...214
# left to calculate...213
# left to calculate...212
# left to calculate...211
# left to calculate...210
# left to calculate...209
# left to calculate...208
# left to calculate...207
# left to calculate...206
# left to calculate...205
# left to calculate...204
# left to calculate...203
# left to calculate...202
# left to calculate...201
# left to calculate...200
# left to calculate...199
# left to calculate...198
# left to calculate...197
# left to calculate...196
# left to calculate...195
# left to calculate...194
# left to calculate...193
# left to calculate...192
# left to calculate...191
# left to calculate...190
# left to calculate...189
# left to calculate...188
# left to calculate...187
# left to calculate...186
# left to calculate...185
# left to calculate...184
# left to calculate...183
# left to calculate...182
# left to calculate...181
# left to calculate...180
# left to calculate...179
# left to calculate...178
# left to calculate...177
# left to calculate...176
# left to calculate...175
# left to calculate...174
# left to calculate...173
# left to calculate...172
# left to calculate...171
# left to calculate...170
# left to calculate...169
# left to calculate...168
# left to calculate...167
# left to calculate...166
# left to calculate...165
# left to calculate...164
# left to calculate...163
# left to calculate...162
# left to calculate...161
# left to calculate...160
# left to calculate...159
# left to calculate...158
# left to calculate...157
# left to calculate...156
# left to calculate...155
# left to calculate...154
# left to calculate...153
# left to calculate...152
# left to calculate...151
# left to calculate...150
# left to calculate...149
# left to calculate...148
# left to calculate...147
# left to calculate...146
# left to calculate...145
# left to calculate...144
# left to calculate...143
# left to calculate...142
# left to calculate...141
# left to calculate...140
# left to calculate...139
# left to calculate...138
# left to calculate...137
# left to calculate...136
# left to calculate...135
# left to calculate...134
# left to calculate...133
# left to calculate...132
# left to calculate...131
# left to calculate...130
# left to calculate...129
# left to calculate...128
# left to calculate...127
# left to calculate...126
# left to calculate...125
# left to calculate...124
# left to calculate...123
# left to calculate...122
# left to calculate...121
# left to calculate...120
# left to calculate...119
# left to calculate...118
# left to calculate...117
# left to calculate...116
# left to calculate...115
# left to calculate...114
# left to calculate...113
# left to calculate...112
# left to calculate...111
# left to calculate...110
# left to calculate...109
# left to calculate...108
# left to calculate...107
# left to calculate...106
# left to calculate...105
# left to calculate...104
# left to calculate...103
# left to calculate...102
# left to calculate...101
# left to calculate...100
# left to calculate...99
# left to calculate...98
# left to calculate...97
# left to calculate...96
# left to calculate...95
# left to calculate...94
# left to calculate...93
# left to calculate...92
# left to calculate...91
# left to calculate...90
# left to calculate...89
# left to calculate...88
# left to calculate...87
# left to calculate...86
# left to calculate...85
# left to calculate...84
# left to calculate...83
# left to calculate...82
# left to calculate...81
# left to calculate...80
# left to calculate...79
# left to calculate...78
# left to calculate...77
# left to calculate...76
# left to calculate...75
# left to calculate...74
# left to calculate...73
# left to calculate...72
# left to calculate...71
# left to calculate...70
# left to calculate...69
# left to calculate...68
# left to calculate...67
# left to calculate...66
# left to calculate...65
# left to calculate...64
# left to calculate...63
# left to calculate...62
# left to calculate...61
# left to calculate...60
# left to calculate...59
# left to calculate...58
# left to calculate...57
# left to calculate...56
# left to calculate...55
# left to calculate...54
# left to calculate...53
# left to calculate...52
# left to calculate...51
# left to calculate...50
# left to calculate...49
# left to calculate...48
# left to calculate...47
# left to calculate...46
# left to calculate...45
# left to calculate...44
# left to calculate...43
# left to calculate...42
# left to calculate...41
# left to calculate...40
# left to calculate...39
# left to calculate...38
# left to calculate...37
# left to calculate...36
# left to calculate...35
# left to calculate...34
# left to calculate...33
# left to calculate...32
# left to calculate...31
# left to calculate...30
# left to calculate...29
# left to calculate...28
# left to calculate...27
# left to calculate...26
# left to calculate...25
# left to calculate...24
# left to calculate...23
# left to calculate...22
# left to calculate...21
# left to calculate...20
# left to calculate...19
# left to calculate...18
# left to calculate...17
# left to calculate...16
# left to calculate...15
# left to calculate...14
# left to calculate...13
# left to calculate...12
# left to calculate...11
# left to calculate...10
# left to calculate...9
# left to calculate...8
# left to calculate...7
# left to calculate...6
# left to calculate...5
# left to calculate...4
# left to calculate...3
# left to calculate...2
# left to calculate...1
#                      geometry         x          y      co    no   no2     o3  \
# 569  POINT (5.24543 49.69697)  5.245427  49.696968  240.33  0.07  2.96  60.08
# 652  POINT (5.64543 49.59697)  5.645427  49.596968  250.34  0.12  4.28  60.08
# 610  POINT (5.44543 49.59697)  5.445427  49.596968  250.34  0.08  3.30  60.80
# 631  POINT (5.54543 49.59697)  5.545427  49.596968  250.34  0.08  3.30  60.80
# 653  POINT (5.64543 49.69697)  5.645427  49.696968  247.00  0.08  7.03  53.64
#
#       so2  pm2_5  pm10   nh3  time
# 569  0.57   6.99  7.42  1.30   0.0
# 652  1.01   8.03  8.59  1.44   0.0
# 610  0.87   8.69  9.26  1.65   0.0
# 631  0.87   8.69  9.26  1.65   0.0
# 653  0.98   6.30  6.89  1.17   0.0

# %% [markdown]
# ## Now we will plot the results for Ozone (o3) using matplotlib.

# %%
import math
## Plot
fig, ax = plt.subplots(figsize=(8, 8))
country.plot(ax=ax, facecolor="none", edgecolor="black")
ax.set_axis_off()
ax.set_aspect("equal")
scatter = ax.scatter(insidePts['x'], insidePts['y'], (insidePts['o3']-min(insidePts['o3']))+1, alpha=0.6)
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6, num=4)
legend2 = ax.legend(handles, labels, loc="lower left", ncol = 1, title="o3-level")

# %% [markdown]
# ## Interactive map based on GeoPandas and folium/leaflet.js

# %%
# !pip install mapclassify
import mapclassify
import math
mino3 = min(insidePts["o3"])

print(mino3)
insidePts.explore(
    style_kwds={"style_function": lambda x: {"radius": math.sqrt(math.sqrt(x["properties"]["o3"]-min(insidePts["o3"])))},
                "weight": .4},
)
# Out:
# Requirement already satisfied: mapclassify in /Users/delmelle/miniforge3/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: networkx>=2.7 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from mapclassify) (3.2.1)
# Requirement already satisfied: numpy>=1.23 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from mapclassify) (1.24.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from mapclassify) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from mapclassify) (1.4.0)
# Requirement already satisfied: scipy>=1.8 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from mapclassify) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/delmelle/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# 20.56
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d974ed378411b94d39cd980b6511549 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d974ed378411b94d39cd980b6511549&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d974ed378411b94d39cd980b6511549 = L.map(
#                 &quot;map_6d974ed378411b94d39cd980b6511549&quot;,
#                 {
#                     center: [50.49696843778035, 4.495427198758984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6d974ed378411b94d39cd980b6511549);
#
#
#
#
#
#             var tile_layer_d453545e3f56850d0c371a01e0612a79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d453545e3f56850d0c371a01e0612a79.addTo(map_6d974ed378411b94d39cd980b6511549);
#
#
#             map_6d974ed378411b94d39cd980b6511549.fitBounds(
#                 [[49.59696843778034, 2.645427198758982], [51.396968437780366, 6.345427198758985]],
#                 {}
#             );
#
#
#         function geo_json_afbb506b5c1291ecfa5e26c31343521b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;569&quot;: case &quot;652&quot;: case &quot;673&quot;: case &quot;590&quot;: case &quot;591&quot;: case &quot;570&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.507288068451785, &quot;weight&quot;: 0.4};
#                 case &quot;610&quot;: case &quot;631&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.518630701564142, &quot;weight&quot;: 0.4};
#                 case &quot;653&quot;: case &quot;654&quot;: case &quot;674&quot;: case &quot;675&quot;: case &quot;425&quot;: case &quot;447&quot;: case &quot;426&quot;: case &quot;469&quot;: case &quot;427&quot;: case &quot;383&quot;: case &quot;362&quot;: case &quot;404&quot;: case &quot;384&quot;: case &quot;405&quot;: case &quot;363&quot;: case &quot;364&quot;: case &quot;282&quot;: case &quot;303&quot;: case &quot;324&quot;: case &quot;510&quot;: case &quot;385&quot;: case &quot;406&quot;: case &quot;344&quot;: case &quot;345&quot;: case &quot;511&quot;: case &quot;490&quot;: case &quot;448&quot;: case &quot;55&quot;: case &quot;35&quot;: case &quot;56&quot;: case &quot;36&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;37&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.398233003237876, &quot;weight&quot;: 0.4};
#                 case &quot;611&quot;: case &quot;632&quot;: case &quot;612&quot;: case &quot;633&quot;: case &quot;507&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.484292585361835, &quot;weight&quot;: 0.4};
#                 case &quot;694&quot;: case &quot;531&quot;: case &quot;552&quot;: case &quot;532&quot;: case &quot;553&quot;: case &quot;262&quot;: case &quot;263&quot;: case &quot;241&quot;: case &quot;179&quot;: case &quot;242&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.3852597230972084, &quot;weight&quot;: 0.4};
#                 case &quot;695&quot;: case &quot;367&quot;: case &quot;388&quot;: case &quot;368&quot;: case &quot;389&quot;: case &quot;266&quot;: case &quot;246&quot;: case &quot;267&quot;: case &quot;245&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.2165846247358343, &quot;weight&quot;: 0.4};
#                 case &quot;613&quot;: case &quot;634&quot;: case &quot;635&quot;: case &quot;614&quot;: case &quot;512&quot;: case &quot;513&quot;: case &quot;492&quot;: case &quot;491&quot;: case &quot;203&quot;: case &quot;182&quot;: case &quot;224&quot;: case &quot;161&quot;: case &quot;119&quot;: case &quot;140&quot;: case &quot;141&quot;: case &quot;162&quot;: case &quot;120&quot;: case &quot;183&quot;: case &quot;225&quot;: case &quot;204&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.330731804008438, &quot;weight&quot;: 0.4};
#                 case &quot;655&quot;: case &quot;677&quot;: case &quot;656&quot;: case &quot;493&quot;: case &quot;514&quot;: case &quot;494&quot;: case &quot;515&quot;: case &quot;688&quot;: case &quot;667&quot;: case &quot;668&quot;:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 2.1745427489508584,
